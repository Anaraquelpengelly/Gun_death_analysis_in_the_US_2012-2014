# %%
import csv
f = open('full_data.csv', 'r')
data = csv.reader(f)
data = list(data)

# %%
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', 'BA+'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', 'Some college'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', 'BA+'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', 'BA+']]

# %%
headers = data[0]

# %%
data = data[1:]

# %%
print(headers)
# Out:
# ['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']

# %%
print(data[0:5])
# Out:
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', 'BA+'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', 'Some college'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', 'BA+'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', 'BA+'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', 'HS/GED']]

# %% [markdown]
# ## How many gun deaths happened per year?

# %%
#list comprehension
years=[row[1] for row in data]

# %%
print(years)
# Out:
# ['2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', '2012', ...

# %%
year_counts ={}
for year in years:
    if year not in year_counts:
        year_counts[year] = 1
    else:
        year_counts[year]+=1

# %%
print(year_counts)
# Out:
# {'2012': 33563, '2013': 33636, '2014': 33599}

# %% [markdown]
# ## Do the number of deaths change by month & year?

# %%
import datetime

# %%
dates = [datetime.datetime(year=int(row[1]), month =int(row[2]), day=1) for row in data]

# %%
print(dates[:5])
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 2, 1, 0, 0), datetime.datetime(2012, 2, 1, 0, 0)]

# %%
date_counts ={}
for date in dates:
    if date not in date_counts:
        date_counts[date] = 1
    else:
        date_counts[date]+=1

# %%
print(date_counts)
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 2758, datetime.datetime(2012, 2, 1, 0, 0): 2357, datetime.datetime(2012, 3, 1, 0, 0): 2743, datetime.datetime(2012, 4, 1, 0, 0): 2795, datetime.datetime(2012, 5, 1, 0, 0): 2999, datetime.datetime(2012, 6, 1, 0, 0): 2826, datetime.datetime(2012, 7, 1, 0, 0): 3026, datetime.datetime(2012, 8, 1, 0, 0): 2954, datetime.datetime(2012, 9, 1, 0, 0): 2852, datetime.datetime(2012, 10, 1, 0, 0): 2733, datetime.datetime(2012, 11, 1, 0, 0): 2729, datetime.datetime(2012, 12, 1, 0, 0): 2791, datetime.datetime(2013, 1, 1, 0, 0): 2864, datetime.datetime(2013, 2, 1, 0, 0): 2375, datetime.datetime(2013, 3, 1, 0, 0): 2862, datetime.datetime(2013, 4, 1, 0, 0): 2798, datetime.datetime(2013, 5, 1, 0, 0): 2806, datetime.datetime(2013, 6, 1, 0, 0): 2920, datetime.datetime(2013, 7, 1, 0, 0): 3079, datetime.datetime(2013, 8, 1, 0, 0): 2859, datetime.datetime(2013, 9, 1, 0, 0): 2742, datetime.datetime(2013, 10, 1, 0, 0): 2808, datetime.datetime(2013, 11, 1, 0, 0): 2758, datetime.datetime(2013, 12, 1, 0, 0): 2765, datetime.datetime(2014, 1, 1, 0, 0): 2651, datetime.datetime(2014, 2, 1, 0, 0): 2361, datetime.datetime(2014, 3, 1, 0, 0): 2684, datetime.datetime(2014, 4, 1, 0, 0): 2862, datetime.datetime(2014, 5, 1, 0, 0): 2864, datetime.datetime(2014, 6, 1, 0, 0): 2931, datetime.datetime(2014, 7, 1, 0, 0): 2884, datetime.datetime(2014, 8, 1, 0, 0): 2970, datetime.datetime(2014, 9, 1, 0, 0): 2914, datetime.datetime(2014, 10, 1, 0, 0): 2865, datetime.datetime(2014, 11, 1, 0, 0): 2756, datetime.datetime(2014, 12, 1, 0, 0): 2857}

# %% [markdown]
# ## Do deaths vary with gender and race?

# %%
gender = [row[5] for row in data]

# %%
gender_counts = {}
for gen in gender:
    if gen not in gender_counts:
        gender_counts[gen]=1
    else:
        gender_counts[gen]+=1

# %%
gender_counts
# Out:
# {'F': 14449, 'M': 86349}

# %%
races = [row[7] for row in data]

# %%
print(races)
# Out:
# ['Asian/Pacific Islander', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Black', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'Native American/Native Alaskan', 'White', 'Black', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'Black', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Asian/Pacific Islander', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'Black', 'Native American/Native Alaskan', 'White', 'White', 'Native American/Native Alaskan', 'Hispanic', 'White', 'White', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Hispanic', 'White', 'White', 'Black', 'White', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'Black', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'Black', 'White', 'Black', 'Hispanic', 'White', 'White', 'White', 'Black', 'White', 'White', 'Black', 'Black', 'Black', 'Black', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'Black', 'White', 'Black', 'Black', 'White', 'Black', 'Black', 'White', 'Black', 'Black', 'Black', 'Black', 'Hispanic', 'White', 'White', 'Black', 'White', 'White', 'Black', 'Black', 'White', 'Black', 'White', 'White', 'White', 'Black', 'Black', 'Black', 'White', 'White', 'White', 'Black', 'Black', 'Black', 'White', 'White', 'Black', 'Black', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'Black', 'White', 'White', 'White', 'White', 'Black', 'Black', 'White', 'White', 'White', 'White', 'Black', 'Black', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'Black', 'White', 'White', 'Black', 'Black', 'Black', 'White', 'Black', 'Black', 'White', 'White', 'Black', 'White', 'Hispanic', 'White', 'White', 'White', 'White', 'Black', 'White', 'Black', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'Black', 'White', 'Black', 'White', 'Black', 'White', 'White', 'Black', 'White', 'Black', 'White', 'Black', 'Black', 'White', 'Black', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'Black', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'Black', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'White', 'White', 'White', 'White', 'Black', 'White', 'Black', 'White', 'B ...

# %%
race_counts ={}

for race in races:
    if race not in race_counts:
        race_counts[race] = 1
    else:
        race_counts[race] += 1

# %%
race_counts
# Out:
# {'Asian/Pacific Islander': 1326,
#  'Black': 23296,
#  'Hispanic': 9022,
#  'Native American/Native Alaskan': 917,
#  'White': 66237}

# %%
print(race_counts)
# Out:
# {'Asian/Pacific Islander': 1326, 'White': 66237, 'Native American/Native Alaskan': 917, 'Black': 23296, 'Hispanic': 9022}

# %% [markdown]
# ##### Interstingly,  there are rgouhly 3 times more gun related deaths of white people than of balck people. It would be important to determine how many of these deaths are not due to suicide but to other kinds of intent. We to answer this question we would have to remove all the entries corresponding to suices. From a different angle, it would be interesting to determine if any cultural background is more prone to suicide. That case we would only take the cases where the intent column corresponds to 'suicide'.
# ##### As for gender, strickingly, the number of deaths involving men is roughly 7 to 8 times higher than the number of deaths involving women! Again, it would be interesting to determine what the numbers are for suicide specifically on one hand and for non-suicice deaths specifically on the other.

# %% [markdown]
# ## Gun deaths proportionnally to percentage of race in the population

# %%
i =open('census.csv', 'r')
census = list(csv.reader(i))
census_header = census[0]
census_data = census[1]

# %%
print(census_header)
# Out:
# ['Id', 'Year', 'Id', 'Sex', 'Id', 'Hispanic Origin', 'Id', 'Id2', 'Geography', 'Total', 'Race Alone - White', 'Race Alone - Hispanic', 'Race Alone - Black or African American', 'Race Alone - American Indian and Alaska Native', 'Race Alone - Asian', 'Race Alone - Native Hawaiian and Other Pacific Islander', 'Two or More Races']

# %%
print(census_data)
# Out:
# ['cen42010', 'April 1, 2010 Census', 'totsex', 'Both Sexes', 'tothisp', 'Total', '0100000US', '', 'United States', '308745538', '197318956', '44618105', '40250635', '3739506', '15159516', '674625', '6984195']

# %%
mapping = {'Asian/Pacific Islander' : (674625+15159516), 'White':197318956, 'Native American/Native Alaskan':3739506, 'Black': 40250635, 'Hispanic': 44618105}

# %%
race_per_hundredk={}

for race in race_counts:
    race_per_hundredk[race] = race_counts[race]/mapping[race]* 100000

# %%
print(race_per_hundredk)
# Out:
# {'Asian/Pacific Islander': 8.374309664161762, 'White': 33.56849303419181, 'Native American/Native Alaskan': 24.521955573811088, 'Black': 57.8773477735196, 'Hispanic': 20.220491210910907}

# %% [markdown]
# ## Filtering by intent

# %% [markdown]
# ### Homicides

# %%
intents = [row[3] for row in data]
races = [row[7] for row in data]

# %%
print(intents[:5], races[:5])
# Out:
# ['Suicide', 'Suicide', 'Suicide', 'Suicide', 'Suicide'] ['Asian/Pacific Islander', 'White', 'White', 'White', 'White']

# %%
homicide_rate_counts={}
for i, race in enumerate(races):
    if intents[i] == 'Homicide':
        if race not in homicide_rate_counts:
            homicide_rate_counts[race] = 1
        else: 
            homicide_rate_counts[race] += 1

# %%
print(homicide_rate_counts)
# Out:
# {'White': 9147, 'Asian/Pacific Islander': 559, 'Black': 19510, 'Native American/Native Alaskan': 326, 'Hispanic': 5634}

# %%
#Calculate the rate proportionally to the total number of individuals of the race, and per 100,000
hom_rate_per_hundredk={}

for race in homicide_rate_counts:
    hom_rate_per_hundredk[race] = homicide_rate_counts[race]/mapping[race]* 100000

# %%
print(hom_rate_per_hundredk)
# Out:
# {'White': 4.6356417981453335, 'Asian/Pacific Islander': 3.530346230970155, 'Black': 48.471284987180944, 'Native American/Native Alaskan': 8.717729026240365, 'Hispanic': 12.627161104219914}

# %% [markdown]
# ### Suicides

# %%
#lets create a function to study the differnt intents per race
def intent_per_race(intent):
    intent_rate_counts={}
    for i, race in enumerate(races):
        if intents[i] == intent:
            if race not in intent_rate_counts:
                intent_rate_counts[race] = 1
            else: 
                intent_rate_counts[race] += 1
    return intent_rate_counts

# %%
suicide_rate_counts=intent_per_race('Suicide')

# %%
print(suicide_rate_counts)
# Out:
# {'Asian/Pacific Islander': 745, 'White': 55372, 'Native American/Native Alaskan': 555, 'Black': 3332, 'Hispanic': 3171}

# %%
#Calculate the rate proportionally to the total number of individuals of the race, and per 100,000
suicide_rate_per_100k = {}
for race in suicide_rate_counts:
    suicide_rate_per_100k[race]=suicide_rate_counts[race]/mapping[race]*100000

suicide_rate_per_100k
# Out:
# {'Asian/Pacific Islander': 4.705023152187416,
#  'Black': 8.278130270491385,
#  'Hispanic': 7.106980451097149,
#  'Native American/Native Alaskan': 14.841532544673013,
#  'White': 28.06217969245692}

# %%
#It is also possible to look at the suicide and the homocide rates per gender
